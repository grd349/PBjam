# %%
import pbjam as pb
import matplotlib.pyplot as plt
import numpy as np
import lightkurve as lk 
import sys
import astropy.units as units
import pandas as pd
import lightkurve as lk
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
kic = '4448777'
numax = [220.0, 3.0]
dnu = [16.97, 0.05]
teff = [4750, 100]
bp_rp = [1.34, 0.1]

# %%
lc = lk.search_lightcurvefile(kic, quarter=1).download().PDCSAP_FLUX.normalize().flatten(window_length=401)
for q in range(2,17):
    lc = lc.append(lk.search_lightcurvefile(kic, quarter=q).download().PDCSAP_FLUX.normalize().flatten(window_length=401))

# %%
lc = lc.remove_outliers(4)
lc.plot()

# %%
pg = lc.to_periodogram(normalization='psd', minimum_frequency=100.0).flatten()

# %%
pg.plot()

# %%
ep = pb.epsilon()
result = ep(dnu=dnu, numax=numax, teff=teff, bp_rp=bp_rp, bw_fac=1.0)

# %%
ep.plot_corner();

# %%
ep.plot(pg);

# %%
asy = pb.asy_peakbag.asymptotic_fit(pg.frequency.value, pg.power.value, 
                                    ep.samples, 
                                    teff, bp_rp, 
                                    nthreads=1, norders=10,
                                    store_chains=True)

# %%
asy.plot_start();

# %%
asy_result = asy.run(burnin=1000, niter=1000)

# %%
asy.plot();

# %%
asy.plot_corner();

# %%
import pbjam
import importlib
importlib.reload(pbjam)
pbag = pbjam.peakbag(pg.frequency.value, pg.power.value, asy_result)

# %%
import pickle

edict = {'f': pg.frequency.value, 'p': pg.power.value, 'a': asy_result}

pickle_out = open("pb.pickle","wb")
pickle.dump(edict, pickle_out)
pickle_out.close()

# %%
pbag.plot_start_model();

# %%
pbag.sample(model_type='simple', cores=4, tune=1500)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [back, height2, height0, width2, width0, l2, l0]
# Sampling 4 chains: 100%|██████████| 8000/8000 [07:14<00:00,  6.72draws/s]
# The acceptance probability does not match the target. It is 0.8844754933579762, but should be close to 0.8. Try to increase the number of tuning steps.
# The gelman-rubin statistic is larger than 1.2 for some parameters.
# The estimated number of effective samples is smaller than 200 for some parameters.
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [back, height2, height0, width2, width0, l2, l0]
# Sampling 4 chains:   1%|          | 79/14000 [00:03<10:28, 22.16draws/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, **kwargs)
#     968             with sampler:
# --> 969                 for draw in sampler:
#     970                     trace = traces[draw.chain - chain]
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/parallel_sampling.py in __iter__(self)
#     392         while self._active:
# --> 393             draw = ProcessAdapter.recv_draw(self._active)
#     394             proc, is_last, draw, tuning, stats, warns = draw
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/parallel_sampling.py in recv_draw(processes, timeout)
#     283         pipes = [proc._msg_pipe for proc in processes]
# --> 284         ready = multiprocessing.connection.wait(pipes)
#     285         if not ready:
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/multiprocessing/connection.py in wait(object_list, timeout)
#     910             while True:
# --> 911                 ready = selector.select(timeout)
#     912                 if ready:
#
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/selectors.py in select(self, timeout)
#     375             try:
# --> 376                 fd_event_list = self._poll.poll(timeout)
#     377             except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-e3081122d357> in <module>()
# ----> 1 pbag.sample(model_type='simple', cores=4, tune=1500)
#
# ~/Code/PBjam/pbjam/peakbag.py in sample(self, model_type, tune, target_accept, cores, maxiter)
#     350                                          init='adapt_diag',
#     351                                          target_accept=target_accept,
# --> 352                                          progressbar=True)
#     353             Rhat_max = np.max([v.max() for k, v in pm.diagnostics.gelman_rubin(self.samples).items()])
#     354             niter += 1
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/sampling.py in sample(draws, step, init, n_init, start, trace, chain_idx, chains, cores, tune, progressbar, model, random_seed, discard_tuned_samples, compute_convergence_checks, **kwargs)
#     435             _print_step_hierarchy(step)
#     436             try:
# --> 437                 trace = _mp_sample(**sample_args)
#     438             except pickle.PickleError:
#     439                 _log.warning("Could not pickle model, sampling singlethreaded.")
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/sampling.py in _mp_sample(draws, tune, step, chains, cores, chain, random_seed, start, progressbar, trace, model, **kwargs)
#     989         return MultiTrace(traces)
#     990     except KeyboardInterrupt:
# --> 991         traces, length = _choose_chains(traces, tune)
#     992         return MultiTrace(traces)[:length]
#     993     finally:
#
# ~/Library/Python/3.6/lib/python/site-packages/pymc3/sampling.py in _choose_chains(traces, tune)
#    1005     lengths = [max(0, len(trace) - tune) for trace in traces]
#    1006     if not sum(lengths):
# -> 1007         raise ValueError('Not enough samples to build a trace.')
#    1008
#    1009     idxs = np.argsort(lengths)[::-1]
#
# ValueError: Not enough samples to build a trace.

# %%
pbag.plot_fit(thin=1);
