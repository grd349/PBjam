# %%
import pbjam as pb
from pbjam.jar import session
import matplotlib.pyplot as plt
import numpy as np
import lightkurve as lk 
import sys

# %%
kic = '4448777'
numax = [220.0, 3.0]
dnu = [16.97, 0.01]
teff = [4750, 100]
bp_rp = [1.34, 0.01]

# %%
# Initialize a jam session with a single star:
jam_sess = session(ID = [kic], numax = [numax], dnu = [dnu], teff = [teff], bp_rp = [bp_rp], 
                   nthreads=1, use_cached=False)

# %%
# Result is always a list of star class instances
# Taking the first one as an example
star = jam_sess.stars[0]

# %%
star.asymptotic_modeid(norders = 7)
# Out:
# Burningham
# Sampling

# %%
fig = star.plot_asyfit()

# %%
from pbjam import peakbag 
import pymc3 as pm
import importlib
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
importlib.reload(peakbag)
pb = peakbag.peakbag(star.f, star.s, star.asy_result)

# %%
pb.plot_start_model()

# %%
pb.sample(model_type='simple', cores=4, tune=1500)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [back, height2, height0, width2, width0, l2, l0]
# Sampling 4 chains: 100%|██████████| 8000/8000 [04:31<00:00, 29.50draws/s]
# There were 5 divergences after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# There were 21 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.01449335793149627, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 3 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6132137907182619, but should be close to 0.8. Try to increase the number of tuning steps.
# The gelman-rubin statistic is larger than 1.4 for some parameters. The sampler did not converge.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.summary(pb.samples)
# Out:
#                   mean         sd  mc_error     hpd_2.5    hpd_97.5  \
# l0__0       159.839041   0.011996  0.000383  159.813873  159.861636
# l0__1       176.267537   0.017004  0.000467  176.232186  176.298676
# l0__2       192.920000   0.014718  0.000427  192.888394  192.945963
# l0__3       209.924658   0.007405  0.000212  209.910015  209.938757
# l0__4       226.816696   0.007570  0.000230  226.802218  226.831687
# l0__5       243.883764   0.015238  0.000365  243.856695  243.915878
# l0__6       261.206485   0.031052  0.000819  261.154339  261.276516
# l2__0       157.120716   1.754752  0.156698  152.836483  159.945337
# l2__1       173.944830   0.026057  0.000701  173.896664  173.995749
# l2__2       190.623711   0.018582  0.000659  190.587178  190.657456
# l2__3       207.617661   0.023481  0.000789  207.572269  207.662137
# l2__4       224.689231   0.017991  0.000510  224.655458  224.727565
# l2__5       241.717480   0.024229  0.000808  241.672546  241.764769
# l2__6       259.019504   0.092187  0.003051  258.833395  259.191898
# back__0       0.942930   0.034785  0.001301    0.873848    1.010000
# back__1       0.907930   0.034349  0.001008    0.840404    0.974455
# back__2       0.892244   0.035463  0.000913    0.825049    0.963982
# back__3       0.944445   0.037974  0.001036    0.872792    1.016246
# back__4       1.025071   0.040423  0.000974    0.946695    1.102101
# height0__0   628.736829  1.002139
# height0__1   984.533533  1.005487
# height0__2   868.009872  0.999329
# height0__3  1118.830807  0.999920
# height0__4   896.639776  1.007405
# height0__5   753.388743  1.001504
# height0__6   663.895125  1.002322
# height2__0    53.912820  1.018512
# height2__1   634.618347  1.004311
# height2__2   718.953380  1.005691
# height2__3  1036.066806  0.999629
# height2__4   775.556610  1.002376
# height2__5   750.494773  1.000579
# height2__6   460.715906  1.001904

# %%
pb.plot_fit(thin=10)

# %%
pb.plot_linewidth()

# %%
pb.plot_height(thin=10)

# %%
pb_gp = peakbag.peakbag(star.f, star.s, star.asy_result)
pb_gp.sample(model_type='model_gp', cores=4, tune=1500)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [back, height2, height0, ln_width2_rotated_, sigma2, intercept2, gradient2, ln_width0_rotated_, sigma0, intercept0, gradient0, l2, l0]
# Sampling 4 chains:   0%|          | 0/8000 [00:00<?, ?draws/s]/usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/theano/tensor/basic.py:6611: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   result[diagonal_slice] = x
# Sampling 4 chains: 100%|██████████| 8000/8000 [34:08<00:00,  1.82draws/s]
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.9188600754050864, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 2 divergences after tuning. Increase `target_accept` or reparameterize.
# There was 1 divergence after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6395079001811704, but should be close to 0.8. Try to increase the number of tuning steps.
# There were 9 divergences after tuning. Increase `target_accept` or reparameterize.
# The acceptance probability does not match the target. It is 0.6329066545302983, but should be close to 0.8. Try to increase the number of tuning steps.
# The gelman-rubin statistic is larger than 1.05 for some parameters. This indicates slight problems during sampling.
# The estimated number of effective samples is smaller than 200 for some parameters.

# %%
pm.summary(pb_gp.samples)
# Out:
#                              mean         sd  mc_error     hpd_2.5  \
# l0__0                  159.839008   0.015763  0.000676  159.811434
# l0__1                  176.267935   0.015399  0.000400  176.240337
# l0__2                  192.918474   0.013147  0.000486  192.893292
# l0__3                  209.924305   0.007081  0.000178  209.910934
# l0__4                  226.816494   0.007647  0.000215  226.802004
# l0__5                  243.883219   0.014062  0.000333  243.855562
# l0__6                  261.206223   0.029009  0.000851  261.148568
# l2__0                  157.555545   1.685251  0.131268  153.078194
# l2__1                  173.937218   0.021419  0.000744  173.900515
# l0__0                  159.871627   403.830836  1.000022
# l0__1                  176.301222  1220.984891  1.000749
# l0__2                  192.944684   263.736076  1.006218
# l0__3                  209.938644  1767.824519  0.999547
# l0__4                  226.832189  1184.621533  1.001108
# l0__5                  243.910015  2208.097419  0.999148
# l0__6                  261.265171   987.651939  1.001018
# l2__0                  160.549578    57.528225  1.061435
# l2__1                  173.983700   478.489376  1.001554
# l2__2                  190.654917  1669.387352  1.000113
# l2__3                  207.659533   179.992948  1.013882
# l2__4                  224.723809   791.463244  1.000349
# l2__5                  241.764049   273.354416  1.014673
# l2__6                  259.190963   878.196318  1.002931
# gradient0                4.527792   307.759549  1.000887
# intercept0              -0.972431   211.725771  1.005013
# ln_width0_rotated___0    2.233968   426.220027  1.000126
# ln_width0_rotated___1    1.857665  1059.124163  1.001484
# ln_width0_rotated___2    0.127466   376.209579  1.003741
# ln_width0_rotated___3    0.942316   945.410947  1.002928
# ln_width0_rotated___4    2.130359   732.420786  1.005777
# ln_width0_rotated___5    1.985958   195.758844  1.007157
# ln_width0_rotated___6    1.819031   401.094320  1.002114
# gradient2                6.544380    94.600274  1.012640
# intercept2              -1.278158    93.706094  1.009691
# ln_width2_rotated___0    1.718356   760.695211  1.004092
# ln_width2_rotated___1    2.756584    57.641798  1.022334
# ln_width2_rotated___2    1.722922   188.367861  1.012229
# ln_width2_rotated___3    0.789257  1383.255150  0.999474
# ln_width2_rotated___4    1.102787   356.639273  1.012060
# ...                           ...          ...       ...
# width0__6                0.440373   117.219516  1.017225
# sigma2                   1.837726   157.542461  1.006494
# ln_width2__0            -1.941067    38.809154  1.030356
# ln_width2__1            -1.776377    59.024363  1.019731
# ln_width2__2            -1.407520   467.713882  1.007298
# ln_width2__3            -1.110286   928.529454  1.002087
# ln_width2__4            -1.122006   359.387056  1.007506
# ln_width2__5            -0.829289   848.616962  1.000295
# ln_width2__6            -0.002686   761.563622  1.005308
# width2__0                0.129587   159.936093  1.005528
# width2__1                0.161202   104.349697  1.009265
# width2__2                0.241843   587.054251  1.004964
# width2__3                0.318314   949.930331  1.002394
# width2__4                0.325450   381.323243  1.007524
# width2__5                0.423885   877.984191  1.000234
# width2__6                0.950184   763.838483  1.004938
# height0__0              14.777139   331.156362  1.014284
# height0__1              17.959257   330.088380  1.017190
# height0__2              33.660693   251.100072  1.013366
# height0__3              80.680666  1050.478292  0.999419
# height0__4             102.400709   871.955597  1.003762
# height0__5              35.293689   371.731469  1.004413
# height0__6               6.962164   108.904621  1.018269
# height2__0              15.013396    68.914302  1.034333
# height2__1              14.459624    58.319288  1.026664
# height2__2               9.806397   565.494267  1.007710
# height2__3              21.366745  1031.658161  1.000818
# height2__4              35.724329   207.009654  1.011746
# height2__5              11.518968   658.200299  1.005150
# height2__6               2.078657   297.763667  1.010438
#
# [83 rows x 7 columns]

# %%
pb_gp.plot_fit(thin=10)

# %%
pb_gp.plot_linewidth(thin=10)
# Out:
# 100%|██████████| 1000/1000 [00:13<00:00, 75.33it/s]

# %%
pb_gp.plot_height(thin=10)
